# %% [markdown]
# <a href="https://colab.research.google.com/github/agiatdonguri/SatelliteFuse/blob/main/hloc_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this notebook, we will build a 3D map of a scene from a small set of images and then localize an image downloaded from the Internet. This demo was contributed by [Philipp Lindenberger](https://github.com/Phil26AT/).

# %%
# !git clone --quiet --recursive https://github.com/cvg/Hierarchical-Localization/
# %cd Hierarchical-Localization
# !pip install --progress-bar off --quiet -e .
# !pip install --progress-bar off --quiet --upgrade plotly

import tqdm, tqdm.notebook
tqdm.tqdm = tqdm.notebook.tqdm  # notebook-friendly progress bars
from pathlib import Path

from hloc import extract_features, match_features, reconstruction, visualization, pairs_from_exhaustive
from hloc.visualization import plot_images, read_image
from hloc.utils import viz_3d
# Out:
# /content/Hierarchical-Localization
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for lightglue (pyproject.toml) ... done

# %% [markdown]
# # Setup
# Here we define some output paths. We will use SuperPoint local features with the SuperGlue matcher, but it's easy to switch to other features like SIFT or R2D2.
#
# Note current code no longer uses SuperPoint + SuperGlue and uses DISK + Lightglue instead. DISK uses reinforcement learning instead of the classic neural network and lightglue is the successor to superglue.

# %%
images = Path('datasets/sacre_coeur')
outputs = Path('outputs/demo/')
# !rm -rf $outputs
sfm_pairs = outputs / 'pairs-sfm.txt'
loc_pairs = outputs / 'pairs-loc.txt'
sfm_dir = outputs / 'sfm'
features = outputs / 'features.h5'
matches = outputs / 'matches.h5'

feature_conf = extract_features.confs['disk']
matcher_conf = match_features.confs['disk+lightglue']

# %% [markdown]
# # 3D mapping
# First we list the images used for mapping. These are all day-time shots of Sacre Coeur.

# %%
references = [str(p.relative_to(images)) for p in (images / 'mapping/').iterdir()]
print(len(references), "mapping images")
plot_images([read_image(images / r) for r in references], dpi=25)
# Out:
# 10 mapping images

# %% [markdown]
# Then we extract features and match them across image pairs. Since we deal with few images, we simply match all pairs exhaustively. For larger scenes, we would use image retrieval, as demonstrated in the other notebooks.

# %%
extract_features.main(feature_conf, images, image_list=references, feature_path=features)
pairs_from_exhaustive.main(sfm_pairs, image_list=references)
match_features.main(matcher_conf, sfm_pairs, features=features, matches=matches);
# Out:
# [2026/05/17 15:12:19 hloc INFO] Extracting local features with configuration:
# {'model': {'max_keypoints': 5000, 'name': 'disk'},
#  'output': 'feats-disk',
#  'preprocessing': {'grayscale': False, 'resize_max': 1600}}
# Downloading: "https://raw.githubusercontent.com/cvlab-epfl/disk/master/depth-save.pth" to /root/.cache/torch/hub/checkpoints/depth-save.pth
#   0%|          | 0.00/4.17M [00:00<?, ?B/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# [2026/05/17 15:12:24 hloc INFO] Finished exporting features.
# [2026/05/17 15:12:24 hloc INFO] Found 45 pairs.
# [2026/05/17 15:12:24 hloc INFO] Matching local features with configuration:
# {'model': {'features': 'disk', 'name': 'lightglue'},
#  'output': 'matches-disk-lightglue'}
# Downloading: "https://github.com/cvg/LightGlue/releases/download/v0.1_arxiv/disk_lightglue.pth" to /root/.cache/torch/hub/checkpoints/disk_lightglue_v0-1_arxiv.pth
#   0%|          | 0.00/45.4M [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
#   0%|          | 0/45 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# [2026/05/17 15:12:37 hloc INFO] Finished exporting matches.

# %% [markdown]
# The we run incremental Structure-from-Motion...

# %%
model = reconstruction.main(sfm_dir, images, sfm_pairs, features, matches, image_list=references)
# Out:
# [2026/05/17 15:13:14 hloc INFO] Writing COLMAP logs to outputs/demo/sfm/colmap.LOG.*
# [2026/05/17 15:13:14 hloc INFO] Creating an empty database...
# [2026/05/17 15:13:14 hloc INFO] Importing images into the database...
# [2026/05/17 15:13:14 hloc INFO] Importing features into the database...
#   0%|          | 0/10 [00:00<?, ?it/s]
# [2026/05/17 15:13:14 hloc INFO] Importing matches into the database...
#   0%|          | 0/45 [00:00<?, ?it/s]
# [2026/05/17 15:13:14 hloc INFO] Performing geometric verification of the matches...
# [2026/05/17 15:13:19 hloc INFO] Running 3D reconstruction...
# Reconstruction 0:   0%|          | 0/10 [00:00<?, ?images/s, registered]
# [2026/05/17 15:13:32 hloc INFO] Reconstructed 1 model(s).
# [2026/05/17 15:13:32 hloc INFO] Largest model is #0 with 10 images.
# [2026/05/17 15:13:32 hloc INFO] Reconstruction statistics:
# Reconstruction:
# 	num_rigs = 10
# 	num_cameras = 10
# 	num_frames = 10
# 	num_reg_frames = 10
# 	num_images = 10
# 	num_points3D = 5895
# 	num_observations = 31651
# 	mean_track_length = 5.36913
# 	mean_observations_per_image = 3165.1
# 	mean_reprojection_error = 0.853352
# 	num_input_images = 10

# %% [markdown]
# and display the reconstructed 3D model:

# %%
fig = viz_3d.init_figure()
viz_3d.plot_reconstruction(fig, model, color='rgba(255,0,0,0.5)', name="mapping", points_rgb=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="5f0167af-c8f6-4aed-824f-c59a43a80c8a" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5f0167af-c8f6-4aed-824f-c59a43a80c8a")) {                    Plotly.newPlot(                        "5f0167af-c8f6-4aed-824f-c59a43a80c8a",                        [{"legendgroup":"mapping","marker":{"color":[[140,140,140],[66,66,61],[109,110,104],[134,136,137],[108,97,77],[184,183,183],[119,114,100],[124,128,122],[60,83,75],[64,64,58],[90,98,91],[138,143,135],[90,96,97],[169,160,151],[116,140,133],[109,129,118],[117,122,118],[179,179,180],[207,210,202],[224,225,220],[133,135,134],[198,204,199],[137,145,144],[128,131,125],[63,63,65],[128,127,124],[80,81,83],[103,108,103],[51,52,53],[98,103,112],[97,98,93],[63,64,61],[35,32,23],[121,116,107],[144,149,145],[141,147,132],[108,109,103],[71,68,60],[121,128,126],[30,33,32],[173,158,139],[135,136,128],[225,224,219],[55,55,61],[88,122,110],[
# %% [markdown]
# We also visualize which keypoints were triangulated into the 3D model.

# %%
visualization.visualize_sfm_2d(model, images, color_by='visibility', n=2)

# %% [markdown]
# # Localization
# Now that we have a 3D map of the scene, we can localize any image. To demonstrate this, we download [a night-time image from Wikimedia](https://commons.wikimedia.org/wiki/File:Paris_-_Basilique_du_Sacr%C3%A9_Coeur,_Montmartre_-_panoramio.jpg).

# %%
# url = "https://upload.wikimedia.org/wikipedia/commons/5/53/Paris_-_Basilique_du_Sacr%C3%A9_Coeur%2C_Montmartre_-_panoramio.jpg"
# try other queries by uncommenting their url
# url = "https://upload.wikimedia.org/wikipedia/commons/5/59/Basilique_du_Sacr%C3%A9-C%C5%93ur_%285430392880%29.jpg"
url = "https://upload.wikimedia.org/wikipedia/commons/8/8e/Sacr%C3%A9_C%C5%93ur_at_night%21_%285865355326%29.jpg"
query = 'query/night.jpg'
image_path = images / query
# !mkdir -p $images/query && wget $url -O $image_path

if not image_path.exists() or image_path.stat().st_size == 0:
    raise FileNotFoundError(f"Image file not found or is empty: {image_path}")

plot_images([read_image(image_path)], dpi=75)
# Out:
# --2026-05-17 15:21:15--  https://upload.wikimedia.org/wikipedia/commons/8/8e/Sacr%C3%A9_C%C5%93ur_at_night%21_%285865355326%29.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.240, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.240|:443... connected.
# HTTP request sent, awaiting response... 429 Too Many Requests (b4a3396)
# 2026-05-17 15:21:15 ERROR 429: Too Many Requests (b4a3396).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_13411/860542181.py in <cell line: 0>()
#       8
#       9 if not image_path.exists() or image_path.stat().st_size == 0:
# ---> 10     raise FileNotFoundError(f"Image file not found or is empty: {image_path}")
#      11
#      12 plot_images([read_image(image_path)], dpi=75)
#
# FileNotFoundError: Image file not found or is empty: datasets/sacre_coeur/query/night.jpg

# %% [markdown]
# Again, we extract features for the query and match them exhaustively with all mapping images that were successfully reconstructed.

# %%
references_registered = [model.images[i].name for i in model.reg_image_ids()]
extract_features.main(feature_conf, images, image_list=[query], feature_path=features, overwrite=True)
pairs_from_exhaustive.main(loc_pairs, image_list=[query], ref_list=references_registered)
match_features.main(matcher_conf, loc_pairs, features=features, matches=matches, overwrite=True);
# Out:
# [2023/07/17 12:49:06 hloc INFO] Extracting local features with configuration:
# {'model': {'max_keypoints': 5000, 'name': 'disk'},
#  'output': 'feats-disk',
#  'preprocessing': {'grayscale': False, 'resize_max': 1600}}
#   0%|          | 0/1 [00:00<?, ?it/s]
# [2023/07/17 12:49:07 hloc INFO] Finished exporting features.
# [2023/07/17 12:49:07 hloc INFO] Found 10 pairs.
# [2023/07/17 12:49:07 hloc INFO] Matching local features with configuration:
# {'model': {'features': 'disk', 'name': 'lightglue'},
#  'output': 'matches-disk-lightglue'}
# Loaded LightGlue model
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning:
#
# This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   0%|          | 0/10 [00:00<?, ?it/s]
# [2023/07/17 12:49:09 hloc INFO] Finished exporting matches.

# %% [markdown]
# We read the EXIF data of the query to infer a rough initial estimate of camera parameters like the focal length. Then we estimate the absolute camera pose using PnP+RANSAC and refine the camera parameters.

# %%
import pycolmap
from hloc.localize_sfm import QueryLocalizer, pose_from_cluster

camera = pycolmap.infer_camera_from_image(images / query)
ref_ids = [model.find_image_with_name(r).image_id for r in references]
conf = {
    "estimation": {"ransac": {"max_error": 12}},
    "refinement": {"refine_focal_length": True, "refine_extra_params": True},
}
localizer = QueryLocalizer(model, conf)
ret, log = pose_from_cluster(localizer, query, camera, ref_ids, features, matches)

print(f'found {ret["num_inliers"]}/{len(ret["inlier_mask"])} inlier correspondences.')
visualization.visualize_loc_from_log(images, query, log, model)
# Out:
# found 3124/4618 inlier correspondences.

# %% [markdown]
# We visualize the correspondences between the query images a few mapping images. We can also visualize the estimated camera pose in the 3D map.

# %%
pose = pycolmap.Image(cam_from_world=ret['cam_from_world'])
viz_3d.plot_camera_colmap(fig, pose, camera, color='rgba(0,255,0,0.5)', name=query, fill=True)
# visualize 2D-3D correspodences
import numpy as np
inl_3d = np.array([model.points3D[pid].xyz for pid in np.array(log['points3D_ids'])[ret['inlier_mask']]])
viz_3d.plot_points(fig, inl_3d, color="lime", ps=1, name=query)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4afd84a5-6076-468d-b961-8385006c98a5" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4afd84a5-6076-468d-b961-8385006c98a5")) {                    Plotly.newPlot(                        "4afd84a5-6076-468d-b961-8385006c98a5",                        [{"legendgroup":"mapping","marker":{"color":[[76,82,84],[180,181,177],[135,136,131],[62,60,54],[108,100,77],[216,212,201],[81,87,87],[114,117,104],[65,71,78],[71,77,83],[164,165,161],[169,167,160],[178,180,173],[132,133,125],[147,150,142],[138,146,150],[125,135,129],[121,116,106],[73,73,71],[156,156,149],[58,58,53],[77,81,81],[97,98,93],[78,86,86],[121,131,124],[218,217,209],[153,154,150],[48,53,52],[12,16,18],[135,137,128],[146,144,131],[74,84,76],[118,126,126],[122,127,125],[146,155,161],[147,148,145],[34,32,19],[16,19,17],[114,119,113],[173,161,139],[160,161,163],[125,127,118],[130,134,130],[100,102,97],[84,89,83],[24,26,24],[206,209,197],[101,112,116],[161,158,149],[170,166,148],[177,179,177],[169,167,160],[152,146,133],[112,108,96],[85,111,97],[128,128,119],[127,133,138],[159,150,133],[118,105,86],[0,0,0],[103,103,93],[161,148,114],[0,0,0],[172,160,134],[